# %% [markdown]
# # **Basics**

# %% [markdown]
# ### **Series**

# %%
print("Yash Uttam")
# Out:
# Yash Uttam

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10, 20, 30]
arr = np.array([60,70,80])
my_dict = {'x':111, 'y':222, 'z':333}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    60
# 1    70
# 2    80
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    60
# b    70
# c    80
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# x    111
# y    222
# z    333
# dtype: int64
